# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('DataBase.csv')
df
# Out:
#                  wz             wy         az             wx     time  \
# 0          4.926625      24.822440  2570396.0  572220.100000  132.619
# 1          4.926625      24.822440  2570396.0  572220.100000  132.619
# 2         10.727650       0.166672  2570395.0      11.538890  132.639
# 3         31.007570      14.552580  2570394.0      35.206760  132.659
# 4         31.007570      14.552580  2570394.0      35.206760  132.659
# ...             ...            ...        ...            ...      ...
# 1435       7.079641  572220.600000  2570381.0       1.142058  151.885
# 1436       7.079641  572220.600000  2570381.0       1.142058  151.885
# 1437       7.599110  572218.900000  2570381.0  572223.100000  151.905
# 1438  572215.100000       8.154285  2570381.0  572219.000000  151.925
# 1439  572215.100000       8.154285  2570381.0  572219.000000  151.925
#
#              ax         ay
# 0     2570567.0  2570318.0
# 1     2570567.0  2570318.0
# 2     2570568.0  2570318.0
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(df.time, df.ax)
plt.grid(); plt.title('Kernel Data')
plt.xlabel('time'); plt.ylabel('response')
plt.show()
