# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output/target/data.csv')
df
# Out:
#       pitch      e     ay  roll   yaw     ax     wy          time       az  \
# 0     -3504  0.576 -75875   -66  1102  10122   7402  2.384186e-07  1003109
# 1     -3535  0.576 -50796   -86  1122    405  21293  8.465290e-02   994472
# 2     -3512  0.576 -65415   -75  1127   6331 -13272  1.922421e-01  1003720
# 3     -3533  0.576 -61509   -87  1132   7642   8147  2.940345e-01   989252
# 4     -3518  0.576 -59611   -78  1134   1672  13078  3.834641e-01  1000142
# ...     ...    ...    ...   ...   ...    ...    ...           ...      ...
# 1034  -3639  1.656 -68334   -89  2023  -8019 -38208  1.033927e+02   989699
# 1035  -3634  1.656 -43882   -94  2022  -3091   6300  1.034937e+02   995739
# 1036  -3628  1.656 -65842   -97  2024  -5972  21442  1.035909e+02   997091
# 1037  -3626  1.656 -40408  -100  2026   7952   4251  1.036941e+02   990678
# 1038  -3625  1.656 -79457  -100  2024  -3130 -27012  1.037943e+02  1009180
#
#          wz     wx   tmp
# 0       844 -26278  48.6
# ...

# %% [markdown]
# align 1 - cabeca pra cima
# align 2 - cabeça pra baixo

# %%
df.yaw.plot()
# Out:
# <Axes: >
