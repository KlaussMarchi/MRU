# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('files/test5/rolling_x/target/data.csv')
df
# Out:
#          ay  roll     wz   tmp     wy  pitch      e     wx       az  \
# 0     -9735 -3351  44339  56.5   6735   -594  0.288  28910   994122
# 1    -12832 -3356  18329  56.5 -18520   -593  0.288 -27558   996188
# 2     -7134 -3356  29671  56.7   5711   -592  0.288 -30478   997481
# 3    -13577 -3353  -4674  56.5 -19853   -593  0.288  26212  1000726
# 4    -11905 -3357 -17612  56.9  29984   -592  0.288   9759   997716
# ...     ...   ...    ...   ...    ...    ...    ...    ...      ...
# 3272  -8211 -3336  19180  57.7 -12527   -642  0.468  14780   995288
# 3273 -10354 -3334    113  57.4  17786   -644  0.468  -6816   994789
# 3274 -15290 -3335  -4123  57.4    658   -642  0.468 -11937   997383
# 3275  -6010 -3334  11121  57.7   3740   -643  0.468  -5677   997417
# 3276 -11773 -3332  -8318  57.4 -29552   -640  0.468  -5880   993636
#
#               time     ax    yaw
# 0     4.768372e-07  58549  10842
# 1     5.126691e-02  60494  10847
# 2     1.569357e-01  60662  10856
# ...

# %% [markdown]
# align 1 - cabeca pra cima
# align 2 - cabeça pra baixo

# %%
df.pitch.plot()
# Out:
# <Axes: >
